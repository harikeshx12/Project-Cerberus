# %% [markdown]
# # Colab Runner — Project Cerberus
#
# This is the only notebook you open. It just pulls the latest code from GitHub and runs it.
# All real code lives in `.py` files, edited in VSCode.

# %% [markdown]
# ## First time setup (run once per fresh runtime)

# %%
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/yourname/project-cerberus
# %cd project-cerberus
# !pip install -q -r requirements.txt
# !python -m spacy download en_core_web_sm -q

# %% [markdown]
# ## Every subsequent run — pull latest code instead of re-cloning

# %%
# %cd /content/project-cerberus
# !git pull

# %% [markdown]
# ## Run Module 1.1 — environment setup check

# %%
# !python phase1/module1_setup.py

# %% [markdown]
# ## Run Module 1.2 — Semantic Equivalence Classifier validation

# %%
# !python phase1/module2_semantic_equivalence.py

# %% [markdown]
# ## Run Module 1.2b — fine-tune on numeric semantics blind spot

# %%
# !python phase1/module2b_finetune_numeric.py

# %% [markdown]
# ## Run Module 1.3 — Variant Generator (back-translation)

# %%
# !python phase1/module3_variant_generator.py

# %% [markdown]
# ## Run Module 1.3b — Syntactic Transformation (standalone test, no filters yet)

# %%
# !python phase1/module3b_syntactic_transform.py

# %% [markdown]
# ## Run Module 1.3c — Fine-tune paraphrase generator on QQP (Strategy C)

# %%
# !python phase1/module3c_paraphrase_finetune.py
